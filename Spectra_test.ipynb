# %%
from NIX_Testing import NIX_Spectra
import matplotlib.pyplot as plt

# %%
# Define where the data lives
data_dir = '/home/ydallilar/Documents/NIX/nixDetBackup/'
data_dir = '/home/ydallilar/Documents/MPE/ERIS/NIX/nixDetBackup/'

NIX_Lamp = NIX_Spectra(data_dir + 'test_images/slit_lamp_on.fits')
NIX_Lamp_off = NIX_Spectra(data_dir + 'test_images/slit_lamp_off.fits')

# %%
bright_line = {'wave': 3133.30, 'xys': [[700, 168], [1500, 180]]}
    
NIX_Lamp.getSpectra1D(bright_line=bright_line, dark=NIX_Lamp_off)

# %%
ref_lines = [{'wave' : 3133.30, 'x' : 158},
             {'wave' : 3288.86, 'x' : 463},
             {'wave' : 3812.00, 'x' : 1478},
             {'wave' : 3896.02, 'x' : 1642}]


NIX_Lamp.calibrate(ref_lines=ref_lines, dark=NIX_Lamp_off)
# Out:
# [[Model]]
#     Model(polynomial)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 4
#     # variables        = 3
#     chi-square         = 0.00758388
#     reduced chi-square = 0.00758388
#     Akaike info crit   = -19.0720997
#     Bayesian info crit = -20.9132166
# [[Variables]]
#     c0:  3052.66334 +/- 0.14727863 (0.00%) (init = 3052.663)
#     c1:  0.50888204 +/- 5.3385e-04 (0.10%) (init = 0.508882)
#     c2:  3.1713e-06 +/- 2.8906e-07 (9.11%) (init = 3.171312e-06)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(c1, c2) = -0.992
#     C(c0, c1) = -0.899
#     C(c0, c2) =  0.851

# %%
NIX_Lamp.subtractContinuum(5)
# Out:
# [[Model]]
#     Model(polynomial)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 7
#     # data points      = 1218
#     # variables        = 6
#     chi-square         = 2.4295e+11
#     reduced chi-square = 2.0045e+08
#     Akaike info crit   = 23289.3920
#     Bayesian info crit = 23320.0218
# [[Variables]]
#     c0:  2.9178e+09 +/- 1.5330e+08 (5.25%) (init = 2.917788e+09)
#     c1: -4190821.09 +/- 216890.852 (5.18%) (init = -4190821)
#     c2:  2402.45733 +/- 122.471802 (5.10%) (init = 2402.457)
#     c3: -0.68716861 +/- 0.03450178 (5.02%) (init = -0.6871686)
#     c4:  9.8074e-05 +/- 4.8490e-06 (4.94%) (init = 9.807438e-05)
#     c5: -5.5877e-09 +/- 2.7199e-10 (4.87%) (init = -5.587742e-09)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(c4, c5) = -1.000
#     C(c3, c4) = -1.000
#     C(c2, c3) = -1.000
#     C(c1, c2) = -1.000
#     C(c0, c1) = -1.000
#     C(c3, c5) =  1.000
#     C(c2, c4) =  1.000
#     C(c1, c3) =  1.000
#     C(c0, c2) =  1.000
#     C(c2, c5) = -0.999
#     C(c1, c4) = -0.999
#     C(c0, c3) = -0.999
#     C(c1, c5) =  0.998
#     C(c0, c4) =  0.998
#     C(c0, c5) = -0.997
# {'c3': -0.68716861457727951, 'c2': 2402.4573300196953, 'c1': -4190821.0913975844, 'c0': 2917788096.7681217, 'c5': -5.5877423290878252e-09, 'c4': 9.807438266106982e-05}
# [2917788096.7681217, -4190821.0913975844, 2402.4573300196953, -0.68716861457727951, 9.807438266106982e-05, -5.5877423290878252e-09]
